# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,10)
y = 2 * x
a = np.linspace(0,10,11)
b = a ** 4

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes1=fig.add_axes([1,0,0.2,0.1])
axes.plot(x,y)
axes.plot(a,b)
axes.set_ylim(0,100)
# Out:
# (0.0, 100.0)
