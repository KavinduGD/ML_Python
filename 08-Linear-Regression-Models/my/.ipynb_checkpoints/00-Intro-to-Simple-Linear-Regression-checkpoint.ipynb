# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df["total_spend"]=df["TV"]+df["radio"]+df["newspaper"]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df,x="total_spend",y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
sns.regplot(data=df,x="total_spend",y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = df['total_spend']
y = df['sales']

# %%
np.polyfit(x=X,y=y,deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potentional_spends=np.linspace(0,500,100)

# %%
predicted_sales=0.048687888*potentional_spends+4.24302822

# %%
plt.plot(potentional_spends,predicted_sales)

# %%
sns.scatterplot(x="total_spend",y="sales",data=df)
plt.plot(potentional_spends,predicted_sales)

# %%
sns.scatterplot(x=potentional_spends,y=predicted_sales)
# Out:
# <Axes: >

# %%
np.polyfit
