# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("./data-files/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
plt.figure(figsize=(4,2),dpi=100)
sns.boxplot(x="math score",data=df)
# Out:
# <Axes: xlabel='math score'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.boxplot(x="math score",data=df,y="parental level of education")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.boxplot(y="math score",data=df,x="parental level of education")
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.boxplot(x="math score",data=df,y="parental level of education",hue="gender",orient="h",width=0.5)
plt.legend(bbox_to_anchor=(1.05,1))

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x="math score",data=df)
# Out:
# <Axes: xlabel='math score'>

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x="math score",data=df,y="parental level of education")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",hue="gender")

plt.legend(bbox_to_anchor=(1.15,1))

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",hue="gender",split=True)

plt.legend(bbox_to_anchor=(1.15,1))

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",hue="gender",inner=None)

plt.legend(bbox_to_anchor=(1.15,1))

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",inner=None)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",inner="box")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",inner="quartile")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",inner="stick")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x="math score",data=df,y="parental level of education",bw_method=0.1)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
sns.swarmplot(x="math score",data=df)
# Out:
# <Axes: xlabel='math score'>
# C:\Users\kavin\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="math score",data=df,size=2)
# Out:
# <Axes: xlabel='math score'>

# %%
sns.swarmplot(x="math score",data=df,y="gender",size=3)
# Out:
# <Axes: xlabel='math score', ylabel='gender'>

# %%
sns.swarmplot(x="math score",data=df,y="gender",size=3)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
sns.swarmplot(x="math score",data=df,y="parental level of education",hue="gender",size=3)
plt.legend(bbox_to_anchor=(1.25,1))

# %%
sns.swarmplot(x="math score",data=df,y="parental level of education",hue="gender",size=3,dodge=True)
plt.legend(bbox_to_anchor=(1.25,1))

# %%
sns.boxenplot(x="math score",data=df)
# Out:
# <Axes: xlabel='math score'>

# %%
sns.boxenplot(x="math score",data=df,y="parental level of education")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
sns.boxenplot(x="math score",data=df,y="parental level of education",hue="gender")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>
