# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
df=pd.read_csv("./data-files/country_table.csv")

# %%
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df=df.set_index("Countries")

# %%
df=df.drop("Life expectancy",axis=1)

# %%
sns.heatmap(data=df,linewidths=0.9,annot=True)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(data=df,linewidths=0.9,annot=True,cmap="viridis")
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(data=df,linewidths=0.9,annot=True,cmap="viridis",center=40)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(data=df,linewidths=0.9,annot=True,cmap="viridis",center=1)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.clustermap(df)

# %%
sns.clustermap(df,annot=True)

# %%
sns.clustermap(df,annot=True,col_cluster=False)
